# %% [markdown]
# # 머신러닝의 분류

# %% [markdown]
# > **supervised leanung**
#
# : 지도학습
#
# 타겟 (예측하려는 대상) 이 있어야 하고 그것에 대한 데이터가 있어야한다.
#
# ex) 아파트 가격을 예측함 -> 아파트가격이 곧 타겟
#
#
# > **unsupervised leaning**
#
# : 비지도학습
#
# 타겟값이 지정되지 않는 학습 방법, 어떤것을 예측하려는 목적을 가지지 않음
#
# ex) 클러스터링
#
# - 타겟값이 없기 때문에 컴퓨터가 알아서 데이터를 묶음
#
#
# > **ReInforcement Leaning**
#
# : 강화학습
#
# 보상과 처벌을 기준으로 학습을 함. 올바른 방향으로 나아갈 수 있도록 학습함
#
# 수 많은 데이터를 통해 어떤 수를 두었을 때 보상이 되고 처벌이 되는지를 스스로 학습하여
#
# 최선의 수를 둘 수 있도록 함.

# %% [markdown]
# #  Supervised-Leaning의 문제 유형

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > **Regression** (회귀)
#
# 분류할 수 없는, 일종의 연속된 숫자가 타겟값인 경우
#
# ex) 아파트 가격 예측, 주가예측, 중고차 가격 예측
#
# >**Classification**(분류)
#
# 분류할 수 있는 데이터를 가진 타겟값인 경우
#
# ex) 암에 걸릴 환자인지, 이탈할 고객인지 예측하기 -> Y or  N으로 나눌 수 있음ex) 아파트 가격 예측, 주가예측, 중고차 가격 예측

# %% [markdown]
# # 머신러닝과 딥러닝의 관계

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 딥러닝은 머신러닝에 포함되고, 머신러닝은 인공지능에 포함됨
#
# **A.I** (인공지능)
#
# 인간의 지능을 모방하려는 모든 기술
#
# ex) 머신러닝
# <br/>
# <br>
# **Machine Learning**
#
# 데이터를 기반으로 스스로 패턴을 학습하고 예측하는 기술
#
# 데이터에서 규칙을 스스로 학습함
#
# ex) 회귀, 의사결정나무, SVM, 랜덤 포레스트 등
# <br/>
# <br>
#
# **Deep Learning**
#
# 인공신경망을 여러 층으로 쌓아 고차원 문제를 해결.
#
# ex) 이미지 처리(CNN), 음성 인식(RNN), 자연어 처리(Transformer, BERT) 등

# %% [markdown]
# # 확률의 개요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 확률은 수로 표현함으로써 우리가 다양한 수학적 모델을 적용할 수 있게 한다.

# %% [markdown]
# * **확률이 사용되는 예시**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 위 예시에서 1을 스펨메일, 0을 정상메일이라고 했을 경우 도출된 7/10 확률은 이 예시의 **기댓값**이라고 할 수 있다.
#
# > 기계학습 모델을 확률적으로 이해하기
#
# * 우리는 N개의 학습 데이터로 기계학습 모델을 학습한다.
# * 일반적으로 기계학습 모델의 출력은 "확률"형태를 띤다.
# * 예시 1) 이미지 분류 모델 θ가 이미지 χ에 대해서 75% 확률로 고양이일 것이라고 예측했다.
# * 예시 2) 글쓰기 모델 θ는 "나는 밥을" 이후에 "먹었다" 라는 단어가 나올 확률을 42%로 예측했다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 다양한 문제상황에서 확률을 계산하기 위해서는 경우의 수를 알아야한다.
# * 경우의 수를 계산하는 방법에는 순열(permutation)과 조합(combination)이 있다.

# %% [markdown]
# >**순열**
#
# *  서로 다른 n개에서 r개를 중복 없이 뽑아 특정한 순서로 나열하는 것을 의미함
# *  모든 순열의 수 (경우의 수)는 다음의 공식으로 계산할 수 있다.
#
# 1) 순열의 수 공식(n=r일 때)
#
# ![image.png](data:image/png;base64,...)
#
# 2) 순열의 수 공식(n != r) 일때
# *  **[참고]**  0!은 1 이다.
#
# ![image.png](data:image/png;base64,...)

# %%
# 파이썬을 이용한 순열 계산
from itertools import permutations

arr= ['A','B','C']
# 원소 중에서 2개를 뽑는 모든 순열 계산
result = list(permutations(arr,2))
print(result)
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'A'), ('B', 'C'), ('C', 'A'), ('C', 'B')]

# %% [markdown]
# >  **조합**
#
# * 서로 다른 n개에서 r 개를 **중복없이** 순서를 고려하지 않고 뽑는 것을 의미한다.
# * 모든 조합의 수(경우의 수)는 다음의 공식으로 계산할 수 있다.
# * 조합의 수 공식
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 조합(combination)  예시 - 샴(Siamese) 네트워크
#
# * 딥러닝 아키텍처 중에서 샴 네트워크가 있다.
# * 두 개의 이미지를 받아서, 두 이미지가 유사하다면 1을, 다르다면 0을 출력한다.
# * 이때 N개의 이미지로 구성된 데이터 세트가 있을 때 , 매번 2개의 이미지를 뽑아서 2개의 이미지를 네트워크의 입력으로 넣는다. 이 경우, 두 이미지에 대하여 순서는 상관없다.
# * 예를 들어 4개의 이미지가 있을 때 순서는 고려하지 않고 2개의 이미지를 뽑는 경우의 수는?
# *전체 이미지를 {1,2,3,4}라고 했을 때, 가능한 모든 경우는 다음과 같다.
# * 모든 경우: [1,2],[1,3],[1,4],[2,3],[2,4],[3,4]
# * 경우의 수: 4 * 3 / 2 = 6

# %%
# 파이썬을 이용한 조합 계산
from itertools import combinations

arr= ['A','B','C']
#  원소 중에서 2개를 뽑는 모든 조합 계산

result = list(combinations(arr, 2))
print(result)
# Out:
# [('A', 'B'), ('A', 'C'), ('B', 'C')]

# %% [markdown]
# > **중복 순열** (Permutation with Repetition)
#
# * 서로 다른 n개에서 중복을 포함해 r개를 뽑아 특정한 순서로 나열하는 것을 의미한다.
# * 모든 중복 순열의 수(경우의 수)는 다음의 공식으로 계산할 수 있다.
# * 중복 순열의 수 공식
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 중복 순열 예시
#
# * 세 개의 숫자 1, 2, 3을 이용해 만들 수 있는 두 자리 자연수의 개수는?
# * (단, 같은 숫자를 여러 번 사용하거나, 사용하지 않는 숫자가 있어도 괜찮다.)
# * 모든 경우: $11, 12, 13, 21, 22, 23,31, 32, 33$
# *  경우의 수:$3^2 = 9$

# %%
# 파이썬을 이용하면 전체 중복 순열을 간단히 계산할 수 있다.

from itertools import product

arr = ['A', 'B', 'C']
# 원소 중에서 2개를 뽑는 모든 중복 순열 계산
result = list(product(arr, repeat=2))
print(result)
# Out:
# [('A', 'A'), ('A', 'B'), ('A', 'C'), ('B', 'A'), ('B', 'B'), ('B', 'C'), ('C', 'A'), ('C', 'B'), ('C', 'C')]

# %% [markdown]
# > **중복조합** (Combination with Repetition)
#
# * 서로 다른 n개에서 중복을 포함해 순서를 고려하지 않고 r개를 뽑는 것을 의미한다.
# * 모든 중복 조합의 수 (경우의 수)는 다음의 공식으로 계산할 수 있다.
# * 중복조합의 수 공식
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 중복조합 예시
#
# * 딥러닝에서는 학습된 여러 모델의 결과를 활용하여 최종적인 결과를 생성하는 앙상블(ensemble)방법이 존재한다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 서로 다른 딥러닝 아키텍처 1번, 2번, 3번이 존재한다.
# * 중복을 허용하여 4개를 골라서 딥러닝 모델 4개를 학습하고자 한다.
#
# **[문제]**  이때 가능한 학습의 모든 조합의 수는?
#
# * 같은 아키텍처를 여러 번 사용하거나, 선택하지 않는 아키텍처가 있어도 된다.
#
# ![image.png](data:image/png;base64,...)

# %%
# 파이썬을 이용하여 전체 중복조합을 계산할 수 있다.

from itertools import combinations_with_replacement

arr=['A','B','C']
# 원소 중에서 2개를 뽑는 모든 중복 조합 계산
result = list(combinations_with_replacement(arr,2))
print(result)
# Out:
# [('A', 'A'), ('A', 'B'), ('A', 'C'), ('B', 'B'), ('B', 'C'), ('C', 'C')]

# %% [markdown]
# > **확률** (Probability)
#
# * $S$를 전체사건 (event)의 집합(표본 공간 = sample space)라고 하자.
# * 사건 $X$가 일어나는 경우의 수 / 전체 경우의 수 = $n(X)/n(S)$
# *앞면에 1, 뒷면에 0이 쓰여 있는 2개의 동전을 2번 던졌을 때, 눈금의 합이 1일 확률은?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > **통계적 확률**
#
# * 주사위를 던졌을 때 눈금이 5가 나올 확률은 1/6다.
# * 그렇다면, 6번 던졌을 때 , 반드시 눈금이 5인 경우가 나올까?
# *시행 횟수가 적기 때문에 장담할 수 없다.
# * 하지만 6,000번 던졌다면 , 1,000번에 가까운 횟수로 등장할 것이다.
#
#
# ---
#
#
#
# * 동일한 시행을  $N$번 반복해 사건 $X$가 발생한 횟수를 $R$이라고 하자.
# * 시행 횟수 $N$을 무한히 크게 만들었을 때, $R/N$이 수렴하는 값을  사건 $X$의 통계적 확률이라 한다.
# * 프로그램을 이용해 많은 시행을 수행하여, 확률을 계산해 볼 수 있다.
# * 목표 확률: 0.167
#
# ![image.png](data:image/png;base64,...)
